# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('Data/df1', index_col=0)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
# plot the histogram of column A
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'A'}>, <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'C'}>, <Axes: title={'center': 'D'}>]],
#       dtype=object)

# %%
df1.hist(column="A")
# Out:
# array([[<Axes: title={'center': 'A'}>]], dtype=object)

# %%
sns.displot(df1['A'], kind='kde')
# Out:
# /Users/mac2022/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df1['A'], kind='hist', kde=True, bins=10)
# Out:
# /Users/mac2022/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Bar plot

# %%
# Ex2 - Read the df2 dataset and then plot bar plot of the dataset with different libraries
df2 = pd.read_csv('Data/df2')

# %%
len(df2)
# Out:
# 10

# %%
df2.plot(kind='bar')
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2.boxplot(column=['a', 'b', 'c'])
# Out:
# <Axes: >

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='a'>, <Axes: ylabel='b'>, <Axes: ylabel='c'>,
#        <Axes: ylabel='d'>], dtype=object)

# %%
df2[['a', 'b']].plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='a'>, <Axes: ylabel='b'>], dtype=object)

# %%
df2['a'].plot.pie(subplots=True, startangle=90)
# Out:
# array([<Axes: ylabel='a'>], dtype=object)

# %%
# Ex3 - Read the df1 dataset and then use the scatter plot of the dataset with different libraries
df1.plot.scatter(x='A', y='B', c='C', s=df1['C']*100)
# Out:
# /Users/mac2022/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df=pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.plot.hexbin(x='a', y='b', gridsize = 25, cmap='coolwarm')
# Out:
# <Axes: xlabel='a', ylabel='b'>
